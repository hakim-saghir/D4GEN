# %%
import matplotlib
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.preprocessing import LabelEncoder

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import warnings
warnings.filterwarnings("ignore")

from IPython.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
RAW_DATA_PATH = Path("C:/Users/TUF15/Desktop/D4GEN/d4gen_project/data/raw/raw_dataset.csv")

# %%
raw_dataset = pd.read_csv(RAW_DATA_PATH, delimiter=';')

# %%
print ('Database has %i rows and %i columns' % (raw_dataset.shape[0], raw_dataset.shape[1]))
# Out:
# Database has 1950 rows and 397 columns

# %%
raw_dataset = raw_dataset.dropna(how='all')

# %%
le = LabelEncoder()

# Encoder les colonnes
for col in raw_dataset.columns:
    try:
        if not pd.api.types.is_numeric_dtype(raw_dataset[col]):
            raw_dataset[col] = le.fit_transform(df[col])
        elif raw_dataset[col].dtype == 'bool':
            raw_dataset[col] = raw_dataset[col].astype('int')
    except:
        print(col, 'Having problem')
# Out:
# adm_pds_col3 Having problem
# adm_pds_revasc Having problem
# Sexe Having problem
# dph_debutsympt_heure Having problem
# Mode de vie Having problem
# Lateralite Having problem
# Activité Having problem
# Activité cat Having problem
# Ethnie Having problem
# ATCD HTA Having problem
# ATCD diabete Having problem
# ATCD hyperchol Having problem
# ATCD tabac Having problem
# consotabac Having problem
# ATCD Conso alcool Having problem
# IMC Having problem
# imc_statut Having problem
# ATCD FA connu Having problem
# di_fa_type Having problem
# ATCD_avc Having problem
# ATCD_inf cereb Having problem
# ATCD _hemo cereb Having problem
# ATCD coronarien Having problem
# ATCD_aomi Having problem
# TT_antiagrégant Having problem
# TT_AVK Having problem
# TT_AOD Having problem
# Détail TT_desc Having problem
# histo_déficit moteur Having problem
# histo_trouble sensitif Having problem
# histo_aphasie Having problem
# histo_dysarthie Having problem
# histo_trouble visuel Having problem
# ...

# %%
from sklearn.decomposition import PCA
# appliquer la PCA sur les vecteurs numériques
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X.toarray())

# visualiser les résultats de la PCA
df = pd.DataFrame(X_pca, columns=["PC1", "PC2"])
print(df)

import pandas as pd

# données textuelles
texts = ["Ceci est un exemple de texte.",
         "Un autre exemple de texte.",
         "Et encore un autre exemple de texte."]

# transformer les données textuelles en vecteurs numériques avec TF-IDF
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(texts)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
def text_to_value(x):
    print(vectorizer.fit_transform(x))

# %%
vectorizer = TfidfVectorizer()
raw_dataset['adm_pds_col3'].apply([text_to_value])
# Out:
#   (0, 0)	1.0
#   (1, 0)	1.0
#   (2, 0)	1.0
#   (3, 0)	1.0
#   (4, 0)	1.0
#   (5, 0)	1.0
#   (6, 0)	1.0
#   (7, 0)	1.0
#   (8, 0)	1.0
#   (9, 0)	1.0
#   (10, 0)	1.0
#   (11, 0)	1.0
#   (12, 0)	1.0
#   (13, 0)	1.0
#   (14, 0)	1.0
#   (15, 0)	1.0
#   (16, 0)	1.0
#   (17, 0)	1.0
#   (18, 0)	1.0
#   (19, 0)	1.0
#   (20, 0)	1.0
#   (21, 0)	1.0
#   (22, 0)	1.0
#   (23, 0)	1.0
#   (24, 0)	1.0
#   :	:
#   (1925, 0)	1.0
#   (1926, 0)	1.0
#   (1927, 0)	1.0
#   (1928, 0)	1.0
#   (1929, 0)	1.0
#   (1930, 0)	1.0
#   (1931, 0)	1.0
#   (1932, 0)	1.0
#   (1933, 0)	1.0
#   (1934, 0)	1.0
#   (1935, 0)	1.0
#   (1936, 0)	1.0
#   (1937, 0)	1.0
#   (1938, 0)	1.0
#   (1939, 0)	1.0
#   (1940, 0)	1.0
#   (1941, 0)	1.0
#   (1942, 0)	1.0
#   (1943, 0)	1.0
#   (1944, 0)	1.0
#   (1945, 0)	1.0
#   (1946, 0)	1.0
#   (1947, 0)	1.0
#   (1948, 0)	1.0
#   (1949, 0)	1.0
# ---------------------------------------------------------------------------
# ...
